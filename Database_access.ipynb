# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.types import Integer
import math
import keyring
from pprint import pprint
import requests
import json
import folium

# set connection parameters
dbName = 'happy_road'
dbUser = 'orms0027'
dbPass = keyring.get_password('tpostgres', 'orms0027')
dbHost = 'usvcs-tpostgres.uservices.umn.edu'

# %%
# convert GeoJson coordinate list into a properly formatted 
# strings to pass to OSRM API
def geojson_to_OSRM_strings(geojson):
    
    #generate a coordinate pair string
    coord_separator = ','
    coord_pair_separator = ';'
    coord_list = []
    for coord_pair in geojson['coordinates']:
        coord_pair_string = coord_separator.join([str(coord) for coord in coord_pair])
        coord_list.append(coord_pair_string)
    coord_pairs_string = coord_pair_separator.join(coord_list)
    
    # generate a timestamp string
    timestamp_separator = ';'
    timestamp_string_list = []
    for timestamp in geojson['properties']['timestamps']:
        timestamp_string_list.append(str(int(timestamp / 1000)))
    timestamps_string = timestamp_separator.join(timestamp_string_list)
    
    # generate a string of accuracies to use as a search radius
    
    radius_separator = ';'
    radius_string_list = []
    for radius in geojson['properties']['accuracies']:
        radius_string_list.append(str(radius))
    radiuses_string = radius_separator.join(radius_string_list)

    
    return coord_pairs_string, timestamps_string, radiuses_string

# %%
# returns the arguments needed to pass a match request to the docker instance of OSRM
# see OSRM backend documentation at https://github.com/Project-OSRM/osrm-backend

def match(coord_string,
          mode='biking', 
          steps='true',
          tidy='true',
          geometries='geojson',
          gaps='ignore',
          overview='false', 
          annotations='nodes',
          timestamps=False,
          radiuses=False):

    url = 'http://localhost:5000/match/v1/{}/{}?steps={}&geometries={}&tidy={}&gaps={}'.format(mode, coord_string, steps, geometries, tidy, gaps)

    if overview:
        url += '&overview={}'.format(overview)
    if annotations:
        url += '&annotations={}'.format(annotations)
    if radiuses:
        url += '&radiuses={}'.format(radiuses)
    if timestamps:
        url +='&timestamps={}'.format(timestamps)
    
    return url

# %%
# given a URL string suitable for passing to OSRM, return the JSON output from OSRM
def match_json(url):
    # gets the returned json from OSRM
    r = requests.get(url)
    
    # convert to dictionary
    matchings_dict = json.loads(r.text)
    
    return matchings_dict

# %%
# takes a trip id, the URL from the match function, and a python dict in GeoJson feature collection
# format.  Passes the URL to OSRM which returns a JSON string, which includes the matchings.  
# Converts the JSON string to a feature in GeoJson format for each matching, and adds it to 
# the feature collection dictionary.  Returns the feature collection dictionary.

# the index option is the starting feature id value

# the timestamps value is a list of the times for the input GPS points

def matchings_geojson(tid, url, feature_collection, timestamps, index=0):
    
    matchings_dict = match_json(url)
    
    try:
        # convert the matchings from the dictionary into GeoJson formatted features
        for matching in matchings_dict['matchings']:
            confidence = matching['confidence']
            # initialize a list to store all the timestamps associated with the matching
            timestamps_list = []  
            feature = {
                       'type': 'Feature',
                       'id': index,
                       'geometry': {
                                    'type': 'LineString',
                                    'coordinates': []
                                   },
                       'properties': {
                                    'start_time': None,
                                    'end_time': None,
                                    'confidence': confidence,
                                    'tid': tid
                                    }
                      }

            # loop through the legs and steps of the matching to get a single set of coords for the whole matching
            for leg in matching['legs']:

                # each input GPS point defines a leg in the matched route, so popping the timestamp for each leg into
                # the timestamp list will make a list of all timestamps associated with a matching
                timestamps_list.append(timestamps.pop(0))  

                for step in leg['steps']:
                    feature['geometry']['coordinates'].extend(step['geometry']['coordinates'])

            feature['properties']['start_time'] = timestamps_list[0]

            # the last timestamp in the list is the start time of the last leg.  Add 5 seconds to approximate the actual end time
            feature['properties']['end_time'] = timestamps_list[-1] + 5000 

            # put the feature representing the matching into the feature collection
            feature_collection['features'].append(feature)

            # advance the feature id index 
            index += 1
            
    except:
        print('error during trip {}: {}'.format(tid, matchings_dict['message']))
    
    return feature_collection, index + 1  # return the feature collection and the index of the next feature to add to the collection

# %%
# takes a trip id, the URL from the match function, and a python dict in GeoJson feature collection
# format.  Passes the URL to OSRM which returns a JSON string, which includes the matchings.  
# Converts the JSON string to a point feature in GeoJson format for the first point in each leg, and adds it to 
# the feature collection dictionary.  Returns the feature collection dictionary.

# the index option is the starting feature id value

# the timestamps value is a list of the times for the input GPS points

def leg_points_geojson(tid, url, feature_collection, timestamps, index=0):
    
    matchings_dict = match_json(url)
    
    # convert the matchings from the dictionary into GeoJson formatted features
    for matching in matchings_dict['matchings']:
        confidence = matching['confidence']
        # initialize a list to store all the timestamps associated with the matching
        timestamps_list = []  
        feature = {
                   'type': 'Feature',
                   'id': index,
                   'geometry': {
                                'type': 'Point',
                                'coordinates': []
                               },
                   'properties': {
                                'timestamp': None,
                                'confidence': confidence,
                                'tid': tid
                                }
                  }
        
        # loop through the legs and steps of the matching to get a single set of coords for the whole matching
        for leg in matching['legs']:
            
            # each input GPS point defines a leg in the matched route, so popping the timestamp for each leg will
            # give the correct timestamp for the leg
            feature['properties']['timestamp'] = timestamps.pop(0)  
            
            # the first point in the first step of the leg provides the coordinate of the leg point
            feature['geometry']['coordinates'] = leg['steps'][0]['geometry']['coordinates'][0] 
        
        # put the feature representing the matching into the feature collection
        feature_collection['features'].append(feature)
        
        # advance the feature id index 
        index += 1
    
    return feature_collection, index + 1  # return the feature collection and the index of the next feature to add to the collection

# %%
# return a pandas dataframe for a given trip id, given an enginec
def get_df(tid, engine):
    # get results as a pandas dataframe
    sql = 'SELECT * FROM trip_points WHERE tid = {} ORDER BY location_timestamp'.format(tid)
    df = pd.read_sql_query(sql, con=engine)
    
    # select only the GPS points where the accuracy is better than 25 meters.  This cleans up the input points to
    # the OSRM map matching algorithm and reduces the number of spurious matches
    df = df.loc[df['accuracy'] < 25]
    
    return df

# %%
# for a given trip id, add each matching to a python dict formatted as a geojson feature collection
def matched_trip_geojson(tid, engine, feature_collection=None, feature_index=0): 
    
    # get all GPS points for the trip from the Postgres database as a pandas dataframe
    df = get_df(tid, engine)
    
    # number of pieces to break the trip into, since OSRM can only match 100 pts at a time.  
    # dividing by 100 - len(df)/100 b/c there is a 1 point overlap between chunks
    chunks = int(math.ceil(len(df) / (100 - len(df)/100)))
    
    if chunks == 0: # i.e. the dataframe is empty
        print('error: 0 length chunk size')
        return feature_collection, feature_index
    
    print('working on trip', tid)
    print('chunks:', chunks)
    
    # number of records in each chunk, because we'd like to keep them evenly sized and we want 1 point overlap
    chunk_size = (len(df) // chunks) + 1  


    index = 0  # index of the point to start with
    
    for i in range(chunks):  # for each chunk
        
        print('working on chunk:', i+1)
        
        if i == chunks - 1: # i.e. if this is the last chunk
            chunk_df = df[index:]  # get the dataframe from the index to the end
        else:
            chunk_df = df[index:index+chunk_size]
            
            # advance the index to the first record of the next chunk, which is the same as the last point of the last chunk
            index += chunk_size - 1
        
        # initialize a python dict in geojson format for the chunk
        chunk_geojson = {'type': 'LineString',
                         'properties': {}}
        chunk_geojson['coordinates'] = list(zip(chunk_df['longitude'], chunk_df['latitude']))
        chunk_geojson['properties']['timestamps'] = list(chunk_df['location_timestamp'])
        chunk_geojson['properties']['accuracies'] = list(chunk_df['accuracy'])
        #pprint(chunk_geojson)
        
        # get coordinate, timestamp, and search radius strings suitable for creating a URL to pass to the OSRM API
        chunk_coord_string, chunk_timestamp_string, chunk_radius_string = geojson_to_OSRM_strings(chunk_geojson)
        #print(chunk_coord_string, chunk_timestamp_string, chunk_radius_string)
        
        # create a url string to pass to the OSRM API
        chunk_match_url = match(chunk_coord_string, timestamps=chunk_timestamp_string, radiuses=chunk_radius_string)
        #print(chunk_match_url)
        
        # if no feature collection dictionary was passed to the function, initialize an empty one
        if feature_collection == None:
            feature_collection = {
                "type": "FeatureCollection", 
                "features": []
            }
        
        # uncomment below to return line geojson of the matching
        feature_collection, feature_index = matchings_geojson(tid, chunk_match_url, feature_collection, timestamps=chunk_geojson['properties']['timestamps'], index=feature_index)
        
        # uncomment below to return point geojson of the start point of each leg (i.e. the matched location of each GPS input point)
        #chunk_match_geojson, feature_index = leg_points_geojson(tid, chunk_match_url, feature_collection, timestamps=chunk_geojson['properties']['timestamps'], index=feature_index)
        
        #pprint(chunk_match_geojson)
        
    return feature_collection, feature_index # output the feature index so we can pass it back to this function and maintain unique id's

# %%
# create a database connection engine
engine = create_engine('postgresql://{}:{}@{}:5432/{}'.format(dbUser, dbPass, dbHost, dbName))

# %%
# get a list of all the trip ids for car, bus, and vehicle trips as sqlchemy results query to iterate over
# trip_mode 1 = car, 2 = bus, 3=walk, 4=bike, 5=rail 6=other, 7 = vehicle
auto_trips = engine.execute('SELECT * FROM trip WHERE trip_mode IN (4)')

auto_tripids = [r[0] for r in auto_trips]  # trip id is the first value in the output tuple

# %% [markdown]
# Before running the next line, you need to make sure Docker is running.  Paste the following command into a command prompt to run the OSRM route matching program using the car profile:
#
# docker run -t -i -p 5000:5000 -v "C:\Users\orms0027\Documents\HappyRoads\OSRM:/data" osrm/osrm-backend osrm-routed --algorithm mld /data/seven_county_metro.osrm
#
# you may need to restart Docker to clear the containers if you are swapping to a different profile

# %%
# use the first trip to intitalize the feature collection
test_feature_collection, feature_index = matched_trip_geojson(auto_tripids[0], engine)
# Out:
# working on trip 1546
# chunks: 2
# working on chunk: 1
# working on chunk: 2

# %%
# test to make sure the geojson looks right
pprint(test_feature_collection)
# Out:
# {'features': [{'geometry': {'coordinates': [[-93.255423, 44.962913],
#                                             [-93.255424, 44.962727],
#                                             [-93.255424, 44.962727],
#                                             [-93.255014, 44.962727],
#                                             [-93.255014, 44.962727],
#                                             [-93.255014, 44.962727],
#                                             [-93.255014, 44.962727],
#                                             [-93.255371, 44.962727],
#                                             [-93.255371, 44.962727],
#                                             [-93.255371, 44.962727],
#                                             [-93.255371, 44.962727],
#                                             [-93.254845, 44.962727],
#                                             [-93.254235, 44.962736],
#                                             [-93.254235, 44.962736],
#                                             [-93.254235, 44.962736],
#                                             [-93.254235, 44.962736],
#                                             [-93.254072, 44.962738],
#                                             [-93.254072, 44.962738],
#                                             [-93.254072, 44.962738],
#                                             [-93.254072, 44.962738],
#                                             [-93.25396, 44.96274],
#                                             [-93.25396, 44.96274],
#                                             [-93.25396, 44.962834],
#                                             [-93.25396, 44.962834],
#                                             [-93.253617, 44.962833],
#                                             [-93.253617, 44.962833],
#                                             [-93.253617, 44.962833],
#                                             [-93.253617, 44.962833],
#                                             [-93.253218, 44.962831],
#                                             [-93.253218, 44.962831],
#                                             [-93.253218, 44.962831],
#                                             [-93.253218, 44.962831],
#                                             [-93.253004, 44.96283],
#                                             [-93.253004, 44.96283],
#                                             [-93.253004, 44.96283],
#                                             [-93.253004, 44.96283],
#                                             [-93.253004, 44.96278],
#                                             [-93.253004, 44.96278],
#                                             [-93.252956, 44.962784],
#                                             [-93.252636, 44.962786],
#                                             [-93.252581, 44.962782],
#                                             [-93.252561, 44.962779],
#                                             [-93.252561, 44.962779],
#                                             [-93.252561, 44.962779],
#                                             [-93.252561, 44.962779],
#                                             [-93.252439, 44.96276],
#                                             [-93.252329, 44.962759],
#                                             [-93.252295, 44.962759],
#                                             [-93.252295, 44.962759],
#                                             [-93.252295, 44.962759],
#                                             [-93.252295, 44.962759],
#                                             [-93.252222, 44.96276],
#                                             [-93.252023, 44.962783],
#                                             [-93.252023, 44.962783],
#                                             [-93.252023, 44.962783],
#                                             [-93.252023, 44.962783],
#                                             [-93.251774, 44.962812],
#                                             [-93.251774, 44.962812],
#                                             [-93.251774, 44.962812],
#                                             [-93.251774, 44.962812],
#                                             [-93.251558, 44.962838],
#                                             [-93.251558, 44.962838],
#                                             [-93.251558, 44.962838],
#                                             [-93.251558, 44.962838],
#                                             [-93.251521, 44.962842],
#                                             [-93.251378, 44.962848],
#                                             [-93.251292, 44.962847],
#                                             [-93.251292, 44.962847],
#                                             [-93.251292, 44.962847],
#                                             [-93.251292, 44.962847],
#                                             [-93.251232, 44.962847],
#                                             [-93.251083, 44.962842],
#                                             [-93.250987, 44.962838],
#                                             [-93.250987, 44.962838],
#                                             [-93.250987, 44.962838],
#                                             [-93.250987, 44.962838],
#                                             [-93.250927, 44.962835],
#                                             [-93.250683, 44.962823],
#                                             [-93.250683, 44.962823],
#                                             [-93.250683, 44.962823],
#                                             [-93.250683, 44.962823],
#                                             [-93.250634, 44.962821],
#                                             [-93.249814, 44.962725],
#                                             [-93.249697, 44.962712],
#                                             [-93.249697, 44.962712],
#                                             [-93.249697, 44.962712],
#                                             [-93.249697, 44.962712],
#                                             [-93.248997, 44.962632],
#                                             [-93.248664, 44.962613],
#                                             [-93.24855, 44.962609],
#                                             [-93.24855, 44.962609],
#                                             [-93.24855, 44.962609],
#                                             [-93.24855, 44.962609],
#                                             [-93.248395, 44.962604],
#                                             [-93.248205, 44.962596],
#                                             [-93.248205, 44.962596],
#                                             [-93.248205, 44.962596],
#                                             [-93.248205, 44.962596],
#                                             [-93.248049, 44.962595],
#                                             [-93.24778, 44.962589],
#                                             [-93.247557, 44.962592],
#                                             [-93.247362, 44.962596],
#                                             [-93.247174, 44.962601],
#                                             [-93.247081, 44.962607],
#                                             [-93.247081, 44.962607],
#                                             [-93.247081, 44.962607],
#                                             [-93.247081, 44.962607],
#                                             [-93.246879, 44.96262],
#                                             [-93.246879, 44.96262],
#                                             [-93.246879, 44.96262],
#                                             [-93.246879, 44.96262],
#                                             [-93.246741, 44.962629],
#                                             [-93.2454, 44.96274],
#                                             [-93.2454, 44.96274],
#                                             [-93.2454, 44.96274],
#                                             [-93.2454, 44.96274],
#                                             [-93.245373, 44.962742],
#                                             [-93.245373, 44.962742],
#                                             [-93.245371, 44.962752],
#                                             [-93.245371, 44.962752],
#                                             [-93.245371, 44.962752],
#                                             [-93.245371, 44.962752],
#                                             [-93.245359, 44.962815],
#                                             [-93.245362, 44.962837],
#                                             [-93.245362, 44.962837],
#                                             [-93.245307, 44.962838],
#                                             [-93.245307, 44.962838],
#                                             [-93.245307, 44.962838],
#                                             [-93.245307, 44.962838],
#                                             [-93.245247, 44.962839],
#                                             [-93.245124, 44.962839],
#                                             [-93.245016, 44.962851],
#                                             [-93.245003, 44.962851],
#                                             [-93.245003, 44.962851],
#                                             [-93.245003, 44.962851],
#                                             [-93.245003, 44.962851],
#                                             [-93.244919, 44.962851],
#                                             [-93.244798, 44.962855],
#                                             [-93.244798, 44.962855],
#                                             [-93.244798, 44.962855],
#                                             [-93.244798, 44.962855],
#                                             [-93.24467, 44.962859],
#                                             [-93.244631, 44.962856],
#                                             [-93.244631, 44.962856],
#                                             [-93.244631, 44.962856],
#                                             [-93.244631, 44.962856],
#                                             [-93.244499, 44.962846],
#                                             [-93.244499, 44.962846],
#                                             [-93.244544, 44.962894],
#                                             [-93.244544, 44.962894],
#                                             [-93.244544, 44.962894],
#                                             [-93.244544, 44.962894],
#                                             [-93.244673, 44.963031],
#                                             [-93.244673, 44.963031],
#                                             [-93.244673, 44.963031],
#                                             [-93.244673, 44.963031],
#                                             [-93.2448, 44.963166],
#                                             [-93.2448, 44.963166],
#                                             [-93.2448, 44.963166],
#                                             [-93.244803, 44.963169],
#                                             [-93.244914, 44.963278],
#                                             [-93.244914, 44.963278],
#                                             [-93.244914, 44.963278],
#                                             [-93.244914, 44.963278],
#                                             [-93.244922, 44.963286],
#                                             [-93.244922, 44.963286],
#                                             [-93.244925, 44.963455],
#                                             [-93.244944, 44.963473],
#                                             [-93.244944, 44.963473],
#                                             [-93.244944, 44.963473],
#                                             [-93.244944, 44.963473],
#                                             [-93.24497, 44.963497],
#                                             [-93.24497, 44.963497],
#                                             [-93.244959, 44.963536],
#                                             [-93.244913, 44.963652],
#                                             [-93.244913, 44.963652],
#                                             [-93.244913, 44.963652],
#                                             [-93.244913, 44.963652],
#                                             [-93.244882, 44.963731],
#                                             [-93.244815, 44.963801],
#                                             [-93.244792, 44.963831],
#                                             [-93.244792, 44.963831],
#                                             [-93.244792, 44.963831],
#                                             [-93.244789, 44.963835],
#                                             [-93.244686, 44.963947],
#                                             [-93.244686, 44.963947],
#                                             [-93.244686, 44.963947],
#                                             [-93.244686, 44.963947],
#                                             [-93.244555, 44.964089],
#                                             [-93.244555, 44.964089],
#                                             [-93.244555, 44.964089],
#                                             [-93.244555, 44.964089],
#                                             [-93.244537, 44.964108],
#                                             [-93.244414, 44.964249],
#                                             [-93.244414, 44.964249],
#                                             [-93.244414, 44.964249],
#                                             [-93.244411, 44.964253],
#                                             [-93.244313, 44.96438],
#                                             [-93.244313, 44.96438],
#                                             [-93.244313, 44.96438]],
#                             'type': 'LineString'},
#                'id': 0,
#                'properties': {'confidence': 0.658705,
#                               'end_time': 1476555356000,
#                               'start_time': 1476555148940,
#                               'tid': 1546},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [[-93.244313, 44.96438],
#                                             [-93.244299, 44.964398],
#                                             [-93.244247, 44.964481],
#                                             [-93.244238, 44.9645],
#                                             [-93.244238, 44.9645],
#                                             [-93.244238, 44.9645],
#                                             [-93.244238, 44.9645],
#                                             [-93.244148, 44.964687],
#                                             [-93.244145, 44.964698],
#                                             [-93.244145, 44.964698],
#                                             [-93.244145, 44.964698],
#                                             [-93.244145, 44.964698],
#                                             [-93.244111, 44.964837],
#                                             [-93.244111, 44.964837],
#                                             [-93.244111, 44.964837],
#                                             [-93.244111, 44.964837],
#                                             [-93.244095, 44.964901],
#                                             [-93.244076, 44.965074],
#                                             [-93.244076, 44.965074],
#                                             [-93.244076, 44.965074],
#                                             [-93.244076, 44.965074],
#                                             [-93.244072, 44.965115],
#                                             [-93.244085, 44.965304],
#                                             [-93.244085, 44.965304],
#                                             [-93.244061, 44.965304],
#                                             [-93.244061, 44.965304],
#                                             [-93.244061, 44.965304]],
#                             'type': 'LineString'},
#                'id': 2,
#                'properties': {'confidence': 0.031351,
#                               'end_time': 1476555466000,
#                               'start_time': 1476555441000,
#                               'tid': 1546},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [[-93.244086, 44.965961],
#                                             [-93.244087, 44.966305],
#                                             [-93.244084, 44.966616],
#                                             [-93.244084, 44.966675],
#                                             [-93.244084, 44.966675],
#                                             [-93.244084, 44.966675],
#                                             [-93.244084, 44.966675],
#                                             [-93.244082, 44.967437],
#                                             [-93.244082, 44.967437],
#                                             [-93.244082, 44.967437],
#                                             [-93.244082, 44.967437],
#                                             [-93.244081, 44.967627],
#                                             [-93.244081, 44.967627],
#                                             [-93.244081, 44.967627],
#                                             [-93.244081, 44.967627],
#                                             [-93.244081, 44.967746],
#                                             [-93.24408, 44.967841],
#                                             [-93.24408, 44.967841],
#                                             [-93.24408, 44.967841],
#                                             [-93.24408, 44.967841],
#                                             [-93.244079, 44.967994],
#                                             [-93.244079, 44.967994],
#                                             [-93.244079, 44.967994],
#                                             [-93.244079, 44.967994],
#                                             [-93.244079, 44.968143],
#                                             [-93.244079, 44.968143],
#                                             [-93.244079, 44.968143],
#                                             [-93.244079, 44.968143],
#                                             [-93.244077, 44.968446],
#                                             [-93.244077, 44.968446],
#                                             [-93.244077, 44.968446],
#                                             [-93.244077, 44.968446],
#                                             [-93.244075, 44.968708],
#                                             [-93.244075, 44.968708],
#                                             [-93.244075, 44.968708],
#                                             [-93.244075, 44.968708],
#                                             [-93.244074, 44.968865],
#                                             [-93.244074, 44.968865],
#                                             [-93.244074, 44.968865],
#                                             [-93.244074, 44.968865],
#                                             [-93.244454, 44.969027],
#                                             [-93.244454, 44.969027],
#                                             [-93.244454, 44.969027],
#                                             [-93.244454, 44.969027],
#                                             [-93.244719, 44.96914],
#                                             [-93.244719, 44.96914],
#                                             [-93.244719, 44.96914],
#                                             [-93.244719, 44.96914],
#                                             [-93.244987, 44.969254],
#                                             [-93.244987, 44.969254],
#                                             [-93.244987, 44.969254],
#                                             [-93.244987, 44.969254],
#                                             [-93.245229, 44.969357],
#                                             [-93.245229, 44.969357],
#                                             [-93.245229, 44.969357],
#                                             [-93.245229, 44.969357],
#                                             [-93.245482, 44.969465],
#                                             [-93.245482, 44.969465],
#                                             [-93.245482, 44.969465],
#                                             [-93.245482, 44.969465],
#                                             [-93.245664, 44.969542],
#                                             [-93.245664, 44.969542],
#                                             [-93.245665, 44.969593],
#                                             [-93.245665, 44.969593],
#                                             [-93.245665, 44.969593],
#                                             [-93.245665, 44.969593],
#                                             [-93.245667, 44.969772],
#                                             [-93.245672, 44.969988],
#                                             [-93.24567, 44.970258],
#                                             [-93.24567, 44.970258],
#                                             [-93.24567, 44.970258],
#                                             [-93.24567, 44.970258],
#                                             [-93.245669, 44.970382],
#                                             [-93.245669, 44.970382],
#                                             [-93.245669, 44.970382],
#                                             [-93.245669, 44.970382],
#                                             [-93.245664, 44.970933],
#                                             [-93.245665, 44.971127],
#                                             [-93.24567, 44.971195],
#                                             [-93.24567, 44.971195],
#                                             [-93.24567, 44.971195],
#                                             [-93.24567, 44.971195],
#                                             [-93.245702, 44.971628],
#                                             [-93.245736, 44.971987],
#                                             [-93.245736, 44.971987],
#                                             [-93.245736, 44.971987],
#                                             [-93.245736, 44.971987],
#                                             [-93.245755, 44.972187],
#                                             [-93.245755, 44.972187],
#                                             [-93.245755, 44.972187],
#                                             [-93.245755, 44.972187],
#                                             [-93.245767, 44.972312],
#                                             [-93.245767, 44.972312],
#                                             [-93.245767, 44.972312],
#                                             [-93.245767, 44.972312],
#                                             [-93.245775, 44.972395],
#                                             [-93.245782, 44.97246],
#                                             [-93.245782, 44.97246],
#                                             [-93.245782, 44.97246],
#                                             [-93.245782, 44.97246],
#                                             [-93.245808, 44.97271],
#                                             [-93.245808, 44.97271],
#                                             [-93.245808, 44.97271],
#                                             [-93.245808, 44.97271],
#                                             [-93.245835, 44.972958],
#                                             [-93.245835, 44.972958],
#                                             [-93.245835, 44.972958],
#                                             [-93.245835, 44.972958],
#                                             [-93.245851, 44.973106],
#                                             [-93.245851, 44.973106],
#                                             [-93.245851, 44.973106],
#                                             [-93.245851, 44.973106],
#                                             [-93.24587, 44.97329],
#                                             [-93.245873, 44.973344],
#                                             [-93.245873, 44.973344],
#                                             [-93.245873, 44.973344],
#                                             [-93.245873, 44.973344],
#                                             [-93.245875, 44.973383],
#                                             [-93.245875, 44.973383],
#                                             [-93.24594, 44.973488],
#                                             [-93.24594, 44.973521],
#                                             [-93.24594, 44.973521],
#                                             [-93.24594, 44.973521],
#                                             [-93.24594, 44.973521],
#                                             [-93.245938, 44.973728],
#                                             [-93.245938, 44.973728],
#                                             [-93.245938, 44.973728],
#                                             [-93.245938, 44.973728],
#                                             [-93.245936, 44.973976],
#                                             [-93.245936, 44.973976],
#                                             [-93.245936, 44.973976]],
#                             'type': 'LineString'},
#                'id': 3,
#                'properties': {'confidence': 0.820377,
#                               'end_time': 1476555616000,
#                               'start_time': 1476555466000,
#                               'tid': 1546},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# check the length of auto_tripids to make sure it looks right
len(auto_tripids)
# Out:
# 520

# %%
# get the rest of the trips
for car_trip in auto_tripids[1:]:
    test_feature_collection, feature_index = matched_trip_geojson(car_trip, engine, feature_collection=test_feature_collection, feature_index=feature_index)
# Out:
# working on trip 2128
# chunks: 1
# working on chunk: 1
# working on trip 2137
# chunks: 1
# working on chunk: 1
# working on trip 2209
# chunks: 1
# working on chunk: 1
# working on trip 2303
# chunks: 10
# working on chunk: 1
# error during trip 2303: Could not match the trace.
# working on chunk: 2
# error during trip 2303: Could not match the trace.
# working on chunk: 3
# error during trip 2303: Could not match the trace.
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# error during trip 2303: Could not match the trace.
# working on chunk: 9
# working on chunk: 10
# working on trip 2307
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# error during trip 2307: Could not match the trace.
# working on chunk: 4
# working on chunk: 5
# working on trip 5931
# chunks: 1
# working on chunk: 1
# working on trip 5933
# chunks: 1
# working on chunk: 1
# working on trip 8822
# chunks: 1
# working on chunk: 1
# working on trip 8824
# chunks: 11
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on trip 8836
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 8848
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 8850
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 8876
# chunks: 9
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on trip 8878
# chunks: 22
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on chunk: 14
# working on chunk: 15
# working on chunk: 16
# working on chunk: 17
# working on chunk: 18
# working on chunk: 19
# working on chunk: 20
# working on chunk: 21
# working on chunk: 22
# working on trip 9017
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 9019
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 9021
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 9026
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 9028
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 9030
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 9032
# chunks: 1
# working on chunk: 1
# working on trip 9049
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 9051
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 9061
# chunks: 1
# working on chunk: 1
# working on trip 9063
# chunks: 1
# working on chunk: 1
# working on trip 9065
# chunks: 1
# working on chunk: 1
# working on trip 9069
# chunks: 1
# working on chunk: 1
# working on trip 9071
# chunks: 1
# working on chunk: 1
# working on trip 9073
# chunks: 1
# working on chunk: 1
# working on trip 9304
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 9551
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 12042
# chunks: 1
# working on chunk: 1
# working on trip 13205
# chunks: 1
# working on chunk: 1
# working on trip 13207
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 13209
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 13262
# chunks: 2
# working on chunk: 1
# error during trip 13262: Could not match the trace.
# working on chunk: 2
# working on trip 13268
# chunks: 1
# working on chunk: 1
# working on trip 14193
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14195
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 14197
# chunks: 1
# working on chunk: 1
# working on trip 14199
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14201
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14203
# chunks: 1
# working on chunk: 1
# working on trip 14205
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14207
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14209
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14211
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 14334
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 14336
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 15239
# chunks: 1
# working on chunk: 1
# working on trip 15293
# chunks: 1
# working on chunk: 1
# working on trip 15655
# chunks: 1
# working on chunk: 1
# working on trip 15657
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 16105
# chunks: 1
# working on chunk: 1
# error during trip 16105: Could not find a matching segment for any coordinate.
# working on trip 16164
# chunks: 1
# working on chunk: 1
# working on trip 16294
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 16296
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 16298
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 16591
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# error: 0 length chunk size
# working on trip 18932
# chunks: 1
# working on chunk: 1
# working on trip 21666
# chunks: 1
# working on chunk: 1
# error: 0 length chunk size
# working on trip 26646
# chunks: 1
# working on chunk: 1
# working on trip 28053
# chunks: 13
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on trip 28055
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 28057
# chunks: 1
# working on chunk: 1
# working on trip 28270
# chunks: 14
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on chunk: 14
# working on trip 28767
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 28973
# chunks: 1
# working on chunk: 1
# error during trip 28973: Number of coordinates needs to be at least two.
# working on trip 28982
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 29638
# chunks: 1
# working on chunk: 1
# working on trip 29646
# chunks: 1
# working on chunk: 1
# working on trip 30084
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 30086
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 30088
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 32754
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 32756
# chunks: 1
# working on chunk: 1
# working on trip 32760
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 33334
# chunks: 1
# working on chunk: 1
# working on trip 33336
# chunks: 1
# working on chunk: 1
# working on trip 33342
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 33344
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 33854
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 33859
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 34278
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 34284
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 34286
# chunks: 8
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on trip 34906
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 34908
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 35394
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 35396
# chunks: 1
# working on chunk: 1
# working on trip 35398
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 35402
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 35404
# chunks: 9
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on trip 35795
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 35797
# chunks: 1
# working on chunk: 1
# working on trip 35799
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 35842
# chunks: 14
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 4
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 5
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 6
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 7
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 8
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 9
# working on chunk: 10
# error during trip 35842: Could not find a matching segment for any coordinate.
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on chunk: 14
# working on trip 36263
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 36430
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 37238
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# error during trip 37238: Could not match the trace.
# working on chunk: 4
# working on chunk: 5
# working on trip 37763
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 37765
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 37775
# chunks: 1
# working on chunk: 1
# working on trip 37777
# chunks: 1
# working on chunk: 1
# working on trip 37779
# chunks: 1
# working on chunk: 1
# working on trip 37781
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 37789
# chunks: 1
# working on chunk: 1
# working on trip 37791
# chunks: 1
# working on chunk: 1
# working on trip 37844
# chunks: 1
# working on chunk: 1
# working on trip 37846
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 37848
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 38040
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 38047
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 38368
# chunks: 7
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on trip 38379
# chunks: 1
# working on chunk: 1
# working on trip 38381
# chunks: 1
# working on chunk: 1
# working on trip 38383
# chunks: 8
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on trip 38385
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 38393
# chunks: 1
# working on chunk: 1
# working on trip 38563
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 38565
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 38568
# chunks: 9
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on trip 38570
# chunks: 8
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on trip 38580
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 38741
# chunks: 1
# working on chunk: 1
# working on trip 38749
# chunks: 8
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on trip 38750
# chunks: 1
# working on chunk: 1
# working on trip 38751
# chunks: 1
# working on chunk: 1
# working on trip 38752
# chunks: 1
# working on chunk: 1
# working on trip 38753
# chunks: 1
# working on chunk: 1
# error during trip 38753: Could not match the trace.
# working on trip 38755
# chunks: 1
# working on chunk: 1
# working on trip 38757
# chunks: 1
# working on chunk: 1
# working on trip 38759
# chunks: 1
# working on chunk: 1
# working on trip 38761
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 38765
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 38766
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 38768
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 38977
# chunks: 8
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on trip 38979
# chunks: 1
# working on chunk: 1
# working on trip 39183
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 39185
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 39400
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 39458
# chunks: 9
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on trip 41321
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# error during trip 41321: Could not find a matching segment for any coordinate.
# working on chunk: 4
# working on trip 41615
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 41673
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 41766
# chunks: 1
# working on chunk: 1
# error: 0 length chunk size
# working on trip 42164
# chunks: 10
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on trip 42167
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 42326
# chunks: 7
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on trip 42330
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 42880
# chunks: 10
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on trip 42882
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 42884
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 43270
# chunks: 15
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on chunk: 14
# working on chunk: 15
# working on trip 43272
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 43274
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 43377
# chunks: 1
# working on chunk: 1
# working on trip 43379
# chunks: 1
# working on chunk: 1
# working on trip 43405
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 43473
# chunks: 10
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on trip 43475
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 43477
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 43511
# chunks: 14
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on chunk: 14
# working on trip 43565
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 43681
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 43881
# chunks: 13
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on trip 43884
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 43887
# chunks: 1
# working on chunk: 1
# working on trip 43889
# chunks: 1
# working on chunk: 1
# working on trip 44012
# chunks: 1
# working on chunk: 1
# working on trip 44014
# chunks: 1
# working on chunk: 1
# working on trip 44016
# chunks: 1
# working on chunk: 1
# working on trip 44692
# chunks: 1
# working on chunk: 1
# working on trip 44694
# chunks: 1
# working on chunk: 1
# working on trip 44698
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 44700
# chunks: 1
# working on chunk: 1
# working on trip 44855
# chunks: 1
# working on chunk: 1
# working on trip 44857
# chunks: 1
# working on chunk: 1
# working on trip 44867
# chunks: 1
# working on chunk: 1
# working on trip 44869
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 44871
# chunks: 1
# working on chunk: 1
# working on trip 44873
# chunks: 1
# working on chunk: 1
# working on trip 44877
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 44879
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 44889
# chunks: 1
# working on chunk: 1
# working on trip 44893
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 44903
# chunks: 1
# working on chunk: 1
# working on trip 44905
# chunks: 1
# working on chunk: 1
# working on trip 44907
# chunks: 1
# working on chunk: 1
# working on trip 44909
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 44911
# chunks: 1
# working on chunk: 1
# working on trip 44913
# chunks: 1
# working on chunk: 1
# working on trip 44915
# chunks: 1
# working on chunk: 1
# working on trip 44917
# chunks: 1
# working on chunk: 1
# working on trip 44919
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 44921
# chunks: 1
# working on chunk: 1
# working on trip 44939
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 44941
# chunks: 1
# working on chunk: 1
# working on trip 44943
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 44945
# chunks: 1
# working on chunk: 1
# working on trip 44954
# chunks: 1
# working on chunk: 1
# working on trip 44956
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 44958
# chunks: 1
# working on chunk: 1
# working on trip 44966
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 44970
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 44972
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 44974
# chunks: 1
# working on chunk: 1
# working on trip 44976
# chunks: 1
# working on chunk: 1
# working on trip 45006
# chunks: 1
# working on chunk: 1
# working on trip 45008
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 45010
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 45012
# chunks: 7
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on trip 45014
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 45016
# chunks: 1
# working on chunk: 1
# working on trip 45191
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 45477
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 45485
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 45683
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 45685
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 45853
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 46010
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 46238
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46240
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46242
# chunks: 1
# working on chunk: 1
# working on trip 46244
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46246
# chunks: 1
# working on chunk: 1
# working on trip 46248
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46379
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 46381
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 46385
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46387
# chunks: 1
# working on chunk: 1
# working on trip 46392
# chunks: 10
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on trip 46394
# chunks: 1
# working on chunk: 1
# working on trip 46396
# chunks: 1
# working on chunk: 1
# working on trip 46398
# chunks: 1
# working on chunk: 1
# working on trip 46400
# chunks: 1
# working on chunk: 1
# working on trip 46402
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46477
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46479
# chunks: 1
# working on chunk: 1
# working on trip 46481
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46483
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 46485
# chunks: 1
# working on chunk: 1
# working on trip 46487
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 46789
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 46791
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 46942
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 46944
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 46946
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 46954
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 47042
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 47094
# chunks: 1
# working on chunk: 1
# working on trip 47096
# chunks: 1
# working on chunk: 1
# working on trip 47098
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47100
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47102
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47280
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47282
# chunks: 1
# working on chunk: 1
# working on trip 47290
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47292
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 47369
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47371
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 47649
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 47651
# chunks: 1
# working on chunk: 1
# working on trip 47653
# chunks: 1
# working on chunk: 1
# working on trip 47655
# chunks: 1
# working on chunk: 1
# error during trip 47655: Number of coordinates needs to be at least two.
# working on trip 47657
# chunks: 1
# working on chunk: 1
# working on trip 47659
# chunks: 1
# working on chunk: 1
# working on trip 47661
# chunks: 1
# working on chunk: 1
# working on trip 47663
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 47823
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48050
# chunks: 1
# working on chunk: 1
# working on trip 48055
# chunks: 1
# working on chunk: 1
# working on trip 48058
# chunks: 1
# working on chunk: 1
# working on trip 48061
# chunks: 1
# working on chunk: 1
# working on trip 48068
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48078
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48163
# chunks: 1
# working on chunk: 1
# working on trip 48165
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48269
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48272
# chunks: 1
# working on chunk: 1
# working on trip 48274
# chunks: 1
# working on chunk: 1
# working on trip 48311
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48314
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48316
# chunks: 1
# working on chunk: 1
# working on trip 48336
# chunks: 10
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on trip 48436
# chunks: 1
# working on chunk: 1
# working on trip 48943
# chunks: 1
# working on chunk: 1
# working on trip 48945
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 48947
# chunks: 1
# working on chunk: 1
# working on trip 48979
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 48981
# chunks: 1
# working on chunk: 1
# working on trip 48983
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 48985
# chunks: 7
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on trip 49685
# chunks: 1
# working on chunk: 1
# working on trip 49687
# chunks: 1
# working on chunk: 1
# working on trip 49854
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 49856
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 49940
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 50113
# chunks: 1
# working on chunk: 1
# working on trip 50454
# chunks: 1
# working on chunk: 1
# working on trip 50456
# chunks: 1
# working on chunk: 1
# working on trip 50479
# chunks: 1
# working on chunk: 1
# working on trip 50665
# chunks: 1
# working on chunk: 1
# working on trip 50667
# chunks: 1
# working on chunk: 1
# working on trip 50669
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 50673
# chunks: 1
# working on chunk: 1
# working on trip 50684
# chunks: 1
# working on chunk: 1
# working on trip 50686
# chunks: 1
# working on chunk: 1
# working on trip 51506
# chunks: 1
# working on chunk: 1
# error during trip 51506: Could not match the trace.
# working on trip 51808
# chunks: 1
# working on chunk: 1
# working on trip 51810
# chunks: 1
# working on chunk: 1
# working on trip 51812
# chunks: 1
# working on chunk: 1
# working on trip 51814
# chunks: 1
# working on chunk: 1
# working on trip 51816
# chunks: 1
# working on chunk: 1
# working on trip 51826
# chunks: 1
# working on chunk: 1
# working on trip 51828
# chunks: 1
# working on chunk: 1
# working on trip 51830
# chunks: 1
# working on chunk: 1
# working on trip 51832
# chunks: 1
# working on chunk: 1
# working on trip 51834
# chunks: 1
# working on chunk: 1
# working on trip 51864
# chunks: 1
# working on chunk: 1
# working on trip 51866
# chunks: 1
# working on chunk: 1
# working on trip 52084
# chunks: 1
# working on chunk: 1
# working on trip 52086
# chunks: 1
# working on chunk: 1
# working on trip 52886
# chunks: 1
# working on chunk: 1
# working on trip 52888
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 52890
# chunks: 1
# working on chunk: 1
# working on trip 52892
# chunks: 1
# working on chunk: 1
# working on trip 52903
# chunks: 1
# working on chunk: 1
# working on trip 52911
# chunks: 1
# working on chunk: 1
# working on trip 52915
# chunks: 1
# working on chunk: 1
# working on trip 52919
# chunks: 1
# working on chunk: 1
# working on trip 52923
# chunks: 1
# working on chunk: 1
# working on trip 52925
# chunks: 1
# working on chunk: 1
# working on trip 52927
# chunks: 1
# working on chunk: 1
# working on trip 53140
# chunks: 1
# working on chunk: 1
# working on trip 53155
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 53158
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 53287
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 53851
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# error during trip 53851: Could not find a matching segment for any coordinate.
# working on trip 53853
# chunks: 1
# working on chunk: 1
# error during trip 53853: Could not match the trace.
# working on trip 53855
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 54208
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 54503
# chunks: 1
# working on chunk: 1
# working on trip 54506
# chunks: 1
# working on chunk: 1
# working on trip 54962
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 55504
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 55506
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 56301
# chunks: 1
# working on chunk: 1
# working on trip 56303
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 56458
# chunks: 1
# working on chunk: 1
# working on trip 56460
# chunks: 1
# working on chunk: 1
# working on trip 57149
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 57153
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 57156
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 57158
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 58079
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 58279
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 58281
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 59570
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 59572
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 59574
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 59897
# chunks: 1
# working on chunk: 1
# working on trip 60547
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60549
# chunks: 1
# working on chunk: 1
# working on trip 60551
# chunks: 1
# working on chunk: 1
# working on trip 60553
# chunks: 1
# working on chunk: 1
# working on trip 60555
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 60557
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60559
# chunks: 5
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on trip 60561
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60564
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60569
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60571
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60767
# chunks: 1
# working on chunk: 1
# working on trip 60769
# chunks: 1
# working on chunk: 1
# working on trip 60775
# chunks: 1
# working on chunk: 1
# working on trip 60777
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 60779
# chunks: 1
# working on chunk: 1
# working on trip 60781
# chunks: 1
# working on chunk: 1
# working on trip 61164
# chunks: 1
# working on chunk: 1
# working on trip 61166
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 61168
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 62213
# chunks: 1
# working on chunk: 1
# working on trip 62215
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 62445
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 62449
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 63134
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 63136
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 63137
# chunks: 1
# working on chunk: 1
# working on trip 65173
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 65175
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 65185
# chunks: 1
# working on chunk: 1
# working on trip 65186
# chunks: 1
# working on chunk: 1
# working on trip 66163
# chunks: 1
# working on chunk: 1
# working on trip 66165
# chunks: 1
# working on chunk: 1
# error: 0 length chunk size
# working on trip 66531
# chunks: 1
# working on chunk: 1
# working on trip 66533
# chunks: 1
# working on chunk: 1
# working on trip 66535
# chunks: 1
# working on chunk: 1
# working on trip 66544
# chunks: 1
# working on chunk: 1
# working on trip 66547
# chunks: 1
# working on chunk: 1
# working on trip 66898
# chunks: 1
# working on chunk: 1
# working on trip 68641
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 68643
# chunks: 1
# working on chunk: 1
# working on trip 68787
# chunks: 7
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on trip 68789
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 68791
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 68793
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 68797
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 69324
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 69326
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 73423
# chunks: 1
# working on chunk: 1
# working on trip 73427
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 73429
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 73431
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 73433
# chunks: 1
# working on chunk: 1
# working on trip 74248
# chunks: 1
# working on chunk: 1
# working on trip 74261
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 74263
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 74265
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 74267
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 75624
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 75626
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 75628
# chunks: 1
# working on chunk: 1
# working on trip 75742
# chunks: 1
# working on chunk: 1
# working on trip 75744
# chunks: 1
# working on chunk: 1
# working on trip 76879
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 76881
# chunks: 1
# working on chunk: 1
# working on trip 77081
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77083
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77085
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77087
# chunks: 1
# working on chunk: 1
# working on trip 77089
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 77091
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77093
# chunks: 1
# working on chunk: 1
# working on trip 77116
# chunks: 1
# working on chunk: 1
# working on trip 77141
# chunks: 1
# working on chunk: 1
# working on trip 77845
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77847
# chunks: 1
# working on chunk: 1
# working on trip 77849
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77851
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77885
# chunks: 1
# working on chunk: 1
# working on trip 77909
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77911
# chunks: 1
# working on chunk: 1
# working on trip 77913
# chunks: 1
# working on chunk: 1
# working on trip 77918
# chunks: 1
# working on chunk: 1
# working on trip 77936
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 77939
# chunks: 1
# working on chunk: 1
# working on trip 78592
# chunks: 1
# working on chunk: 1
# working on trip 78594
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 78601
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 78880
# chunks: 1
# working on chunk: 1
# working on trip 78882
# chunks: 1
# working on chunk: 1
# working on trip 78884
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 78887
# chunks: 1
# working on chunk: 1
# working on trip 78889
# chunks: 1
# working on chunk: 1
# working on trip 78892
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 78894
# chunks: 1
# working on chunk: 1
# working on trip 82571
# chunks: 1
# working on chunk: 1
# error during trip 82571: Number of coordinates needs to be at least two.
# working on trip 83988
# chunks: 1
# working on chunk: 1
# working on trip 83992
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 83994
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 83996
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 86439
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 86441
# chunks: 1
# working on chunk: 1
# working on trip 86443
# chunks: 1
# working on chunk: 1
# working on trip 86509
# chunks: 1
# working on chunk: 1
# working on trip 86513
# chunks: 1
# working on chunk: 1
# working on trip 86521
# chunks: 1
# working on chunk: 1
# error during trip 86521: Could not match the trace.
# working on trip 87935
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 88698
# chunks: 1
# working on chunk: 1
# working on trip 88702
# chunks: 1
# working on chunk: 1
# working on trip 89575
# chunks: 1
# working on chunk: 1
# working on trip 89577
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 89754
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 89757
# chunks: 1
# working on chunk: 1
# working on trip 89759
# chunks: 1
# working on chunk: 1
# working on trip 89763
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 89765
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 89768
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 89771
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 89777
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 90141
# chunks: 1
# working on chunk: 1
# working on trip 90147
# chunks: 1
# working on chunk: 1
# working on trip 91718
# chunks: 1
# working on chunk: 1
# working on trip 91822
# chunks: 1
# working on chunk: 1
# working on trip 93472
# chunks: 13
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on chunk: 9
# working on chunk: 10
# working on chunk: 11
# working on chunk: 12
# working on chunk: 13
# working on trip 93474
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 93987
# chunks: 6
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on trip 93989
# chunks: 8
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on chunk: 5
# working on chunk: 6
# working on chunk: 7
# working on chunk: 8
# working on trip 99550
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 100004
# chunks: 1
# working on chunk: 1
# working on trip 101450
# chunks: 1
# working on chunk: 1
# working on trip 158719
# chunks: 1
# working on chunk: 1
# working on trip 158725
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 159595
# chunks: 1
# working on chunk: 1
# working on trip 159597
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 159598
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 159603
# chunks: 1
# working on chunk: 1
# working on trip 159605
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 159607
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 159611
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 161513
# chunks: 1
# working on chunk: 1
# working on trip 161521
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 161534
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 161541
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 161566
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 161963
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 161972
# chunks: 2
# working on chunk: 1
# working on chunk: 2
# working on trip 288608
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 288610
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 289048
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 289053
# chunks: 3
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on trip 289170
# chunks: 4
# working on chunk: 1
# working on chunk: 2
# working on chunk: 3
# working on chunk: 4
# working on trip 289175
# chunks: 1
# working on chunk: 1

# %%
# write the ouput geojson to file
with open('test_features.geojson', 'w') as fh:
    json.dump(test_feature_collection, fh)

# open the file as a geopandas dataframe
gdf = gpd.read_file('test_features.geojson', driver='geojson')
gdf.head()
# Out:
#       start_time       end_time  confidence   tid  \
# 0  1476555148940  1476555356000    0.658705  1546
# 1  1476555441000  1476555466000    0.031351  1546
# 2  1476555466000  1476555616000    0.820377  1546
# 3  1477075200974  1477075268573    0.973637  2128
# 4  1477079790118  1477079795118    0.000000  2137
#
#                                             geometry
# 0  LINESTRING (-93.25542299999999 44.962913, -93....
# 1  LINESTRING (-93.24431300000001 44.96438, -93.2...
# 2  LINESTRING (-93.244086 44.965961, -93.24408699...
# 3  LINESTRING (-93.257244 44.97053, -93.25726 44....
# 4  LINESTRING (-93.262152 44.972605, -93.262152 4...

# %%
# check the length of the gdf
len(gdf)
# Out:
# 6664

# %%
# open the trip data in the postgres database as a pandas dataframe
sql = 'SELECT * FROM trip WHERE tid IN {}'.format(tuple(auto_tripids))
trip_df = pd.read_sql_query(sql, con=engine)
trip_df.head()
# Out:
#     tid   uid  start_timestamp  end_timestamp  trip_mode  duration_sec  \
# 0  2648  1999    1477337340003  1477337370011          5            30
# 1  2743  4000    1477326930056  1477328850001          5          1919
# 2  2745  4000    1477334370023  1477336320005          5          1949
# 3  7771  4006    1479130470006  1479130770019          5           300
# 4  8239  4006    1479218520014  1479219450006          5           929
#
#    distance_m  happy  tired  stressed  sad  pain  meaningful
# 0          58      3      3         2    2     2           1
# 1       17004      5      3         2    2     3           6
# 2       16769      5      2         3    3     2           4
# 3        1895      1      6         1    1     1           7
# 4        6759      1      1         1    1     1           1

# %%
trip_df.to_csv('rail_trips.csv')

# %%
# join the geodataframe to the trip data
merged_gdf = gdf.join(trip_df.set_index('tid'), on='tid')
merged_gdf.head()
# Out:
#       start_time       end_time  confidence   tid  \
# 0  1476555148940  1476555356000    0.658705  1546
# 1  1476555441000  1476555466000    0.031351  1546
# 2  1476555466000  1476555616000    0.820377  1546
# 3  1477075200974  1477075268573    0.973637  2128
# 4  1477079790118  1477079795118    0.000000  2137
#
#                                             geometry   uid  start_timestamp  \
# 0  LINESTRING (-93.25542299999999 44.962913, -93....  2278    1476555090009
# 1  LINESTRING (-93.24431300000001 44.96438, -93.2...  2278    1476555090009
# 2  LINESTRING (-93.244086 44.965961, -93.24408699...  2278    1476555090009
# 3  LINESTRING (-93.257244 44.97053, -93.25726 44....  5001    1477075170030
# 4  LINESTRING (-93.262152 44.972605, -93.262152 4...  5001    1477079790010
#
#    end_timestamp  trip_mode  duration_sec  distance_m  happy  tired  stressed  \
# 0  1476555720014          4           630        2563      0      0         1
# 1  1476555720014          4           630        2563      0      0         1
# 2  1476555720014          4           630        2563      0      0         1
# 3  1477075350011          4           179         914      3      2         2
# 4  1477080150008          4           359        1466      3      1         1
#
#    sad  pain  meaningful
# 0    3     2           0
# 1    3     2           0
# 2    3     2           0
# 3    1     1           1
# 4    1     1           1

# %%
# check the length of the joined file
len(merged_gdf)
# Out:
# 6664

# %%
# output the new dataframe as an Esri shapefile
merged_gdf.to_file('matched_biking_trips',driver ='ESRI Shapefile')
